# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Siddhi\miniconda3\python.exe

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df=pd.read_csv('Book_1.csv')

# %%
df
# Out:
#     Sr No         Company Criteria CGPA Eligible Branches  BE CE  BE ENTC  \
# 0       1           AVAYA            74       All (UG/PG)    2.0      1.0
# 1       2          Ittiam            65       All (UG/PG)    0.0      0.0
# 2       3  Morgan Stanley            73       All (UG/PG)    4.0      0.0
# 3       4  eQ Technologic            60       All (UG/PG)    5.0      5.0
# 4       5         Ubisoft            NC      CE & IT (UG)    0.0      4.0
# ..    ...             ...           ...               ...    ...      ...
# 767   107         Entrata          7.95             CE&IT    3.0      0.0
# 768   108             NCS          6.82            ALL UG    4.0      0.0
# 769     1       Accenture            --            ALL UG    4.0      4.0
# 770     2       TCS Ninja            --            ALL UG    5.0     15.0
# 771     3             IBM            --                --    0.0      0.0
#
#      BE IT  ME  Total Male  Total Female  Total Students Salary LPA  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 772 entries, 0 to 771
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Sr No              772 non-null    object
#  1   Company            772 non-null    object
#  2   Criteria CGPA      767 non-null    object
#  3   Eligible Branches  772 non-null    object
#  4   BE CE              770 non-null    float64
#  5   BE ENTC            770 non-null    float64
#  6   BE IT              750 non-null    float64
#  7   ME                 772 non-null    int64
#  8   Total Male         772 non-null    int64
#  9   Total Female       772 non-null    int64
#  10  Total Students     772 non-null    int64
#  11  Salary LPA         772 non-null    object
#  12  Total _salary      772 non-null    float64
#  13  Year               772 non-null    int64
# dtypes: float64(4), int64(5), object(5)
# memory usage: 84.6+ KB

# %%
df.isnull().sum()
# Out:
# Sr No                 0
# Company               0
# Criteria CGPA         5
# Eligible Branches     0
# BE CE                 2
# BE ENTC               2
# BE IT                22
# ME                    0
# Total Male            0
# Total Female          0
# Total Students        0
# Salary LPA            0
# Total _salary         0
# Year                  0
# dtype: int64

# %%
a=df.duplicated().sum()
print(a)
# Out:
# 0

# %%
df.rename(columns={'Sr No':'sr_no',
                  'Company':'company_name',
                  'Criteria CGPA':'cgpa',
                  'Eligible Branches':'branches',
                  'BE CE':'be_ce',
                  'BE ENTC':'be_entc',
                  'BE IT':'be_it',
                  'ME':'me',
                  'Total Male':'total_male',
                  'Total Female':'total_female',
                  'Total Students':'total_students',
                  'Salary LPA':'salary_lpa',
                   'Total _salary':'total_salary',
                   'Year':'year'
                  },inplace=True)
df
# Out:
#     sr_no    company_name  cgpa      branches  be_ce  be_entc  be_it  me  \
# 0       1           AVAYA    74   All (UG/PG)    2.0      1.0    2.0   0
# 1       2          Ittiam    65   All (UG/PG)    0.0      0.0    1.0   1
# 2       3  Morgan Stanley    73   All (UG/PG)    4.0      0.0    0.0   0
# 3       4  eQ Technologic    60   All (UG/PG)    5.0      5.0    3.0   3
# 4       5         Ubisoft    NC  CE & IT (UG)    0.0      4.0    NaN   1
# ..    ...             ...   ...           ...    ...      ...    ...  ..
# 767   107         Entrata  7.95         CE&IT    3.0      0.0    3.0   0
# 768   108             NCS  6.82        ALL UG    4.0      0.0    2.0   0
# 769     1       Accenture    --        ALL UG    4.0      4.0    0.0   0
# 770     2       TCS Ninja    --        ALL UG    5.0     15.0    1.0   0
# 771     3             IBM    --            --    0.0      0.0    1.0   0
#
#      total_male  total_female  total_students salary_lpa  total_salary  year
# ...

# %%
df.replace('--', pd.NA, inplace=True)  # Replace '--' with NaN (Not Available)
df.replace('-', pd.NA, inplace=True)  # Replace '--' with NaN (Not Available)
df.replace('---', pd.NA, inplace=True)  # Replace '--' with NaN (Not Available)

# %%
df['branches'].nunique()
# Out:
# 36

# %%
# Cleaning function for standardizing branch names
replacements = {
    "all (ug/pg)": "All UG/PG",
    "all(ug/pg)": "All UG/PG",
    "all (ug and pg)": "All UG/PG",
    "all (pg)": "All PG",

    "all(ug)": "All UG",
    "all (ug)": "All UG",
    "all ug": "All UG",
    "all(ug)": "All UG",
    "alL UG": "All UG",
    "ALl UG": "All UG",
    "ALL UG": "All UG",
    "ALL(UG)": "All UG",

    "ce & it (ug)": "CE & IT UG",
    "ce & i t (ug)": "CE & IT UG",
    "ce &i t (ug)": "CE & IT UG",
    "ce & it (ug/pg)": "CE & IT UG/PG",
    "ce & it (ug and pg)": "CE & IT UG/PG",
    "ce & it (ug & pg)": "CE & IT UG/PG",
    "ce & it (ug - female)": "CE & IT UG (Female)",
    "ce+it+entc(girls)": "CE & IT & ENTC (Girls)",
    "ce&it": "CE & IT UG",
    
    "comp&it (ug/pg)": "CE & IT UG/PG",
    "comp&it(ug)": "CE & IT UG",
    "comp & it ug": "CE & IT UG",
    "comp&e&tc(ug)": "CE & ENTC UG",

    "e&tc (ug)": "ENTC UG",
    "e&tc (ug/pg)": "ENTC UG/PG",
    "e&tc (ug&pg)": "ENTC UG/PG",
    "entc": "ENTC",

    "cs & it (ug)": "CE & IT UG",
    "cs&it": "CE & IT UG",
    "cs": "CE",

    "it(ug)": "IT UG",
    
    "all (ug) & ce (pg)": "All UG",
    "all (ug) and ce (pg)": "All UG",
    "all (ug) and ce & it (pg)": "All UG",
    "all (ug - female)": "All UG (Female)",
}

# %%
df['branches'].nunique()
# Out:
# 36

# %%
df['branches'] = df['branches'].str.lower().str.strip().replace(replacements)

# %%
df['branches'].unique()
# Out:
# array(['All UG/PG', 'CE & IT UG', 'CE & IT UG/PG', 'ENTC UG', 'All UG',
#        'CE & ENTC UG', 'ENTC UG/PG', 'All PG', 'CE & IT UG (Female)',
#        'ce (ug)', 'All UG (Female)', 'IT UG', 'CE', <NA>,
#        'CE & IT & ENTC (Girls)', 'ENTC'], dtype=object)

# %%
df['cgpa'] = pd.to_numeric(df['cgpa'], errors="coerce") 
df['be_ce'] = pd.to_numeric(df['be_ce']) 
df['be_entc'] = pd.to_numeric(df['be_entc']) 
df['be_it'] = pd.to_numeric(df['be_it']) 
df['me'] = pd.to_numeric(df['me']) 
df['total_male'] = pd.to_numeric(df['total_male']) 
df['total_female'] = pd.to_numeric(df['total_female']) 
df['total_students'] = pd.to_numeric(df['total_students']) 

df['year'] = df['year'].astype(int) 
df
# Out:
#     sr_no    company_name   cgpa    branches  be_ce  be_entc  be_it  me  \
# 0       1           AVAYA  74.00   All UG/PG    2.0      1.0    2.0   0
# 1       2          Ittiam  65.00   All UG/PG    0.0      0.0    1.0   1
# 2       3  Morgan Stanley  73.00   All UG/PG    4.0      0.0    0.0   0
# 3       4  eQ Technologic  60.00   All UG/PG    5.0      5.0    3.0   3
# 4       5         Ubisoft    NaN  CE & IT UG    0.0      4.0    NaN   1
# ..    ...             ...    ...         ...    ...      ...    ...  ..
# 767   107         Entrata   7.95  CE & IT UG    3.0      0.0    3.0   0
# 768   108             NCS   6.82      All UG    4.0      0.0    2.0   0
# 769     1       Accenture    NaN      All UG    4.0      4.0    0.0   0
# 770     2       TCS Ninja    NaN      All UG    5.0     15.0    1.0   0
# 771     3             IBM    NaN        <NA>    0.0      0.0    1.0   0
#
#      total_male  total_female  total_students salary_lpa  total_salary  year
# ...

# %%
df.loc[df['year'] == 2018, 'cgpa'] = df['cgpa'] / 10

# %%
df['be_it']=df['be_it'].fillna(0.0)
df['be_ce']=df['be_ce'].fillna(0.0)
df['be_entc']=df['be_entc'].fillna(0.0)

# %%
df['branches'].fillna('All UG')
# Out:
# 0       All UG/PG
# 1       All UG/PG
# 2       All UG/PG
# 3       All UG/PG
# 4      CE & IT UG
#           ...
# 767    CE & IT UG
# 768        All UG
# 769        All UG
# 770        All UG
# 771        All UG
# Name: branches, Length: 772, dtype: object

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# !pip install scipy

# %%
df
# Out:
#     sr_no    company_name  cgpa    branches  be_ce  be_entc  be_it  me  \
# 0       1           AVAYA  7.40   All UG/PG    2.0      1.0    2.0   0
# 1       2          Ittiam  6.50   All UG/PG    0.0      0.0    1.0   1
# 2       3  Morgan Stanley  7.30   All UG/PG    4.0      0.0    0.0   0
# 3       4  eQ Technologic  6.00   All UG/PG    5.0      5.0    3.0   3
# 4       5         Ubisoft   NaN  CE & IT UG    0.0      4.0    0.0   1
# ..    ...             ...   ...         ...    ...      ...    ...  ..
# 767   107         Entrata  7.95  CE & IT UG    3.0      0.0    3.0   0
# 768   108             NCS  6.82      All UG    4.0      0.0    2.0   0
# 769     1       Accenture   NaN      All UG    4.0      4.0    0.0   0
# 770     2       TCS Ninja   NaN      All UG    5.0     15.0    1.0   0
# 771     3             IBM   NaN        <NA>    0.0      0.0    1.0   0
#
#      total_male  total_female  total_students salary_lpa  total_salary  year
# ...

# %%
df
# Out:
#     sr_no    company_name  cgpa    branches  be_ce  be_entc  be_it  me  \
# 0       1           AVAYA  7.40   All UG/PG    2.0      1.0    2.0   0
# 1       2          Ittiam  6.50   All UG/PG    0.0      0.0    1.0   1
# 2       3  Morgan Stanley  7.30   All UG/PG    4.0      0.0    0.0   0
# 3       4  eQ Technologic  6.00   All UG/PG    5.0      5.0    3.0   3
# 4       5         Ubisoft   NaN  CE & IT UG    0.0      4.0    0.0   1
# ..    ...             ...   ...         ...    ...      ...    ...  ..
# 767   107         Entrata  7.95  CE & IT UG    3.0      0.0    3.0   0
# 768   108             NCS  6.82      All UG    4.0      0.0    2.0   0
# 769     1       Accenture   NaN      All UG    4.0      4.0    0.0   0
# 770     2       TCS Ninja   NaN      All UG    5.0     15.0    1.0   0
# 771     3             IBM   NaN        <NA>    0.0      0.0    1.0   0
#
#      total_male  total_female  total_students salary_lpa  total_salary  year
# ...

# %%
df.isnull().sum()
# Out:
# sr_no               0
# company_name        0
# cgpa              177
# branches            7
# be_ce               0
# be_entc             0
# be_it               0
# me                  0
# total_male          0
# total_female        0
# total_students      0
# salary_lpa          0
# total_salary        0
# year                0
# dtype: int64

# %%
import seaborn as sns

#
sns.distplot(df.cgpa)

#What Should You Replace Missing Values With?
#If Data is Symmetrical (Normally Distributed) → Use Mean
#If Data is Skewed (like your case) → Use Median
#If Data has Many Repetitions → Use Mode
# Out:
# C:\Users\Siddhi\AppData\Local\Temp\ipykernel_12216\2437664911.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df.cgpa)
# <Axes: xlabel='cgpa', ylabel='Density'>

# %%
df["cgpa"].fillna(df["cgpa"].median(), inplace=True)
df
# Out:
# C:\Users\Siddhi\AppData\Local\Temp\ipykernel_12216\2454771082.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["cgpa"].fillna(df["cgpa"].median(), inplace=True)
#     sr_no    company_name  cgpa    branches  be_ce  be_entc  be_it  me  \
# 0       1           AVAYA  7.40   All UG/PG    2.0      1.0    2.0   0
# 1       2          Ittiam  6.50   All UG/PG    0.0      0.0    1.0   1
# 2       3  Morgan Stanley  7.30   All UG/PG    4.0      0.0    0.0   0
# ...

# %%
df.isnull().sum()
# Out:
# sr_no             0
# company_name      0
# cgpa              0
# branches          7
# be_ce             0
# be_entc           0
# be_it             0
# me                0
# total_male        0
# total_female      0
# total_students    0
# salary_lpa        0
# total_salary      0
# year              0
# dtype: int64

# %%
df["branches"].fillna(df["branches"].mode()[0], inplace=True)
df.head(68)
# Out:
# C:\Users\Siddhi\AppData\Local\Temp\ipykernel_12216\2449751876.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["branches"].fillna(df["branches"].mode()[0], inplace=True)
#    sr_no    company_name  cgpa    branches  be_ce  be_entc  be_it  me  \
# 0      1           AVAYA  7.40   All UG/PG    2.0      1.0    2.0   0
# 1      2          Ittiam  6.50   All UG/PG    0.0      0.0    1.0   1
# 2      3  Morgan Stanley  7.30   All UG/PG    4.0      0.0    0.0   0
# ...

# %% [markdown]
# """OUTLIERNS TECHNIQUES:
# Z-score: This technique is employed for normally
# distributed data, identifying outliers based on standard
# deviations from the mean.
#
# IQR: Suitable for skewed distributions, it involves
# calculating the range between the first and third
# quartiles and identifying outliers outside this range.
#
# Clustering: Techniques such as DBSCAN can identify
# outliers as points that do not belong to any cluster.r"""

# %%
print("Highest allowed",df['cgpa'].mean() + 3*df['cgpa'].std())
print("Lowest allowed",df['cgpa'].mean() - 3*df['cgpa'].std())
# Out:
# Highest allowed 8.54542091053325
# Lowest allowed 5.336718985839806

# %%
df[(df['cgpa'] > 8.54) | (df['cgpa'] < 5.33)]
# Out:
#     sr_no company_name  cgpa branches  be_ce  be_entc  be_it  me  total_male  \
# 613    60   Datametica  8.90   All UG    1.0      1.0    1.0   0           3
# 692    32       E2Open  9.09   All UG    3.0      0.0    2.0   0           2
# 726    66       Corizo  5.00   All UG    0.0      1.0    1.0   0           2
#
#      total_female  total_students salary_lpa  total_salary  year
# 613             0               3         10          30.0  2023
# 692             2               5          8          40.0  2024
# 726             0               2        6.5          13.0  2024

# %%
df
# Out:
#     sr_no    company_name  cgpa    branches  be_ce  be_entc  be_it  me  \
# 0       1           AVAYA  7.40   All UG/PG    2.0      1.0    2.0   0
# 1       2          Ittiam  6.50   All UG/PG    0.0      0.0    1.0   1
# 2       3  Morgan Stanley  7.30   All UG/PG    4.0      0.0    0.0   0
# 3       4  eQ Technologic  6.00   All UG/PG    5.0      5.0    3.0   3
# 4       5         Ubisoft  6.82  CE & IT UG    0.0      4.0    0.0   1
# ..    ...             ...   ...         ...    ...      ...    ...  ..
# 767   107         Entrata  7.95  CE & IT UG    3.0      0.0    3.0   0
# 768   108             NCS  6.82      All UG    4.0      0.0    2.0   0
# 769     1       Accenture  6.82      All UG    4.0      4.0    0.0   0
# 770     2       TCS Ninja  6.82      All UG    5.0     15.0    1.0   0
# 771     3             IBM  6.82      All UG    0.0      0.0    1.0   0
#
#      total_male  total_female  total_students salary_lpa  total_salary  year
# ...

# %%
df.isnull().sum()
# Out:
# sr_no             0
# company_name      0
# cgpa              0
# branches          0
# be_ce             0
# be_entc           0
# be_it             0
# me                0
# total_male        0
# total_female      0
# total_students    0
# salary_lpa        0
# total_salary      0
# year              0
# dtype: int64

# %%
df.to_csv("finalize_1.csv", index=True)
